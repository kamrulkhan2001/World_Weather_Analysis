# %%
import pandas as pd 
import numpy as np 
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module 
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]  
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | kaeo
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 1 | margate
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | half moon bay
# Processing Record 13 of Set 1 | miquelon
# Processing Record 14 of Set 1 | santa rosa
# Processing Record 15 of Set 1 | biryusinsk
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | puerto leguizamo
# Processing Record 19 of Set 1 | tyulyachi
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | puerto ayora
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | praia
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | faya
# Processing Record 27 of Set 1 | chicama
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | kahului
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | guerrero negro
# Processing Record 34 of Set 1 | athens
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 1 | nemuro
# Processing Record 38 of Set 1 | bilibino
# Processing Record 39 of Set 1 | burkhala
# City not found. Skipping...
# Processing Record 40 of Set 1 | mocuba
# Processing Record 41 of Set 1 | karratha
# Processing Record 42 of Set 1 | mangrol
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | gizo
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | lac-megantic
# Processing Record 48 of Set 1 | uvarovo
# Processing Record 49 of Set 1 | beringovskiy
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | brae
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | mehamn
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | mount gambier
# Processing Record 7 of Set 2 | road town
# Processing Record 8 of Set 2 | farmington
# Processing Record 9 of Set 2 | hualmay
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | ponta do sol
# Processing Record 13 of Set 2 | alice springs
# Processing Record 14 of Set 2 | gazimurskiy zavod
# Processing Record 15 of Set 2 | strezhevoy
# Processing Record 16 of Set 2 | whitehorse
# Processing Record 17 of Set 2 | rundu
# Processing Record 18 of Set 2 | alappuzha
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | vila velha
# Processing Record 21 of Set 2 | acari
# Processing Record 22 of Set 2 | bambanglipuro
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | nome
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | camalu
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | geraldton
# Processing Record 29 of Set 2 | dhamnod
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | marzuq
# Processing Record 32 of Set 2 | atkarsk
# Processing Record 33 of Set 2 | xinyang
# Processing Record 34 of Set 2 | dwarka
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | amahai
# Processing Record 37 of Set 2 | najran
# Processing Record 38 of Set 2 | verkhoyansk
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | hirara
# Processing Record 41 of Set 2 | tucuman
# Processing Record 42 of Set 2 | camacha
# Processing Record 43 of Set 2 | praia da vitoria
# Processing Record 44 of Set 2 | zabaykalsk
# Processing Record 45 of Set 2 | jacareacanga
# Processing Record 46 of Set 2 | hasaki
# Processing Record 47 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | bayir
# Processing Record 50 of Set 2 | rabak
# Processing Record 1 of Set 3 | santa maria
# Processing Record 2 of Set 3 | zhanakorgan
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | douala
# Processing Record 5 of Set 3 | batagay
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | varkkallai
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | anadyr
# Processing Record 10 of Set 3 | nanortalik
# Processing Record 11 of Set 3 | villazon
# Processing Record 12 of Set 3 | penarroya-pueblonuevo
# Processing Record 13 of Set 3 | martapura
# Processing Record 14 of Set 3 | yulara
# Processing Record 15 of Set 3 | sitka
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | leningradskiy
# Processing Record 18 of Set 3 | zhezkazgan
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | xaxim
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | aswan
# Processing Record 24 of Set 3 | tuktoyaktuk
# Processing Record 25 of Set 3 | hambantota
# Processing Record 26 of Set 3 | maputo
# Processing Record 27 of Set 3 | cayenne
# Processing Record 28 of Set 3 | todos santos
# Processing Record 29 of Set 3 | wolgast
# Processing Record 30 of Set 3 | savannah bight
# Processing Record 31 of Set 3 | shelburne
# Processing Record 32 of Set 3 | bluff
# Processing Record 33 of Set 3 | aykhal
# Processing Record 34 of Set 3 | auki
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 3 | sao joao da barra
# Processing Record 38 of Set 3 | moi
# Processing Record 39 of Set 3 | noumea
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 3 | palmer
# Processing Record 43 of Set 3 | talnakh
# Processing Record 44 of Set 3 | lahaina
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | twentynine palms
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 3 | whitianga
# Processing Record 50 of Set 3 | cape town
# Processing Record 1 of Set 4 | roma
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | visnes
# Processing Record 4 of Set 4 | codrington
# Processing Record 5 of Set 4 | saiha
# Processing Record 6 of Set 4 | broken hill
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | severo-kurilsk
# Processing Record 9 of Set 4 | isangel
# Processing Record 10 of Set 4 | salina
# Processing Record 11 of Set 4 | dzhebariki-khaya
# Processing Record 12 of Set 4 | mindelo
# Processing Record 13 of Set 4 | port blair
# Processing Record 14 of Set 4 | evensk
# Processing Record 15 of Set 4 | panzhihua
# Processing Record 16 of Set 4 | bodden town
# Processing Record 17 of Set 4 | michigan city
# Processing Record 18 of Set 4 | yelizovo
# Processing Record 19 of Set 4 | great falls
# Processing Record 20 of Set 4 | ruangwa
# Processing Record 21 of Set 4 | bafia
# Processing Record 22 of Set 4 | tomatlan
# Processing Record 23 of Set 4 | baghdad
# Processing Record 24 of Set 4 | santa rosalia
# Processing Record 25 of Set 4 | butaritari
# Processing Record 26 of Set 4 | cololaca
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | cherskiy
# Processing Record 29 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 4 | eston
# Processing Record 31 of Set 4 | maragogi
# Processing Record 32 of Set 4 | ruhengeri
# Processing Record 33 of Set 4 | sydney
# Processing Record 34 of Set 4 | tucupita
# Processing Record 35 of Set 4 | kruisfontein
# Processing Record 36 of Set 4 | kaputa
# Processing Record 37 of Set 4 | nantucket
# Processing Record 38 of Set 4 | havoysund
# Processing Record 39 of Set 4 | ancud
# Processing Record 40 of Set 4 | baltasi
# Processing Record 41 of Set 4 | sambava
# Processing Record 42 of Set 4 | aranos
# Processing Record 43 of Set 4 | yarim
# Processing Record 44 of Set 4 | springbok
# Processing Record 45 of Set 4 | hamilton
# Processing Record 46 of Set 4 | port lincoln
# Processing Record 47 of Set 4 | pacific grove
# Processing Record 48 of Set 4 | yuki
# Processing Record 49 of Set 4 | damietta
# Processing Record 50 of Set 4 | yellowknife
# Processing Record 1 of Set 5 | vostok
# Processing Record 2 of Set 5 | mar del plata
# Processing Record 3 of Set 5 | west bay
# Processing Record 4 of Set 5 | inhambane
# Processing Record 5 of Set 5 | carballo
# Processing Record 6 of Set 5 | luganville
# Processing Record 7 of Set 5 | carutapera
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | hervey bay
# Processing Record 10 of Set 5 | kailua
# Processing Record 11 of Set 5 | jacala
# Processing Record 12 of Set 5 | faanui
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | nouadhibou
# Processing Record 15 of Set 5 | aktash
# Processing Record 16 of Set 5 | labuhan
# Processing Record 17 of Set 5 | ixtapa
# Processing Record 18 of Set 5 | polunochnoye
# Processing Record 19 of Set 5 | kutum
# Processing Record 20 of Set 5 | arona
# Processing Record 21 of Set 5 | avarua
# Processing Record 22 of Set 5 | portland
# Processing Record 23 of Set 5 | senmonorom
# City not found. Skipping...
# Processing Record 24 of Set 5 | morgan city
# Processing Record 25 of Set 5 | margherita
# Processing Record 26 of Set 5 | westport
# Processing Record 27 of Set 5 | horqueta
# Processing Record 28 of Set 5 | necochea
# Processing Record 29 of Set 5 | waitati
# Processing Record 30 of Set 5 | poum
# Processing Record 31 of Set 5 | kloulklubed
# Processing Record 32 of Set 5 | dunedin
# Processing Record 33 of Set 5 | marau
# Processing Record 34 of Set 5 | tonj
# Processing Record 35 of Set 5 | bubaque
# Processing Record 36 of Set 5 | talagang
# Processing Record 37 of Set 5 | harper
# Processing Record 38 of Set 5 | joniskis
# Processing Record 39 of Set 5 | camacupa
# Processing Record 40 of Set 5 | zhigansk
# Processing Record 41 of Set 5 | richard toll
# City not found. Skipping...
# Processing Record 42 of Set 5 | kushmurun
# Processing Record 43 of Set 5 | kongolo
# Processing Record 44 of Set 5 | bosaso
# Processing Record 45 of Set 5 | am timan
# Processing Record 46 of Set 5 | saldanha
# Processing Record 47 of Set 5 | uhlove
# Processing Record 48 of Set 5 | jalu
# Processing Record 49 of Set 5 | arraial do cabo
# Processing Record 50 of Set 5 | kaitangata
# Processing Record 1 of Set 6 | saint-philippe
# Processing Record 2 of Set 6 | kapit
# Processing Record 3 of Set 6 | berlevag
# Processing Record 4 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 5 of Set 6 | mirnyy
# Processing Record 6 of Set 6 | chilca
# Processing Record 7 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | norman wells
# Processing Record 9 of Set 6 | lavrentiya
# Processing Record 10 of Set 6 | tagusao
# Processing Record 11 of Set 6 | mount isa
# Processing Record 12 of Set 6 | pevek
# Processing Record 13 of Set 6 | yalutorovsk
# Processing Record 14 of Set 6 | goito
# Processing Record 15 of Set 6 | neiafu
# Processing Record 16 of Set 6 | westerland
# Processing Record 17 of Set 6 | itaqui
# Processing Record 18 of Set 6 | vila franca do campo
# Processing Record 19 of Set 6 | husavik
# Processing Record 20 of Set 6 | goundam
# Processing Record 21 of Set 6 | alofi
# Processing Record 22 of Set 6 | tautira
# Processing Record 23 of Set 6 | guiratinga
# Processing Record 24 of Set 6 | abu kamal
# Processing Record 25 of Set 6 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 26 of Set 6 | iquique
# Processing Record 27 of Set 6 | ribeira grande
# Processing Record 28 of Set 6 | krasnoarmeysk
# Processing Record 29 of Set 6 | tessalit
# Processing Record 30 of Set 6 | gasa
# Processing Record 31 of Set 6 | handan
# Processing Record 32 of Set 6 | andenes
# Processing Record 33 of Set 6 | hearst
# Processing Record 34 of Set 6 | rokiskis
# Processing Record 35 of Set 6 | olafsvik
# Processing Record 36 of Set 6 | ketchikan
# Processing Record 37 of Set 6 | winnemucca
# Processing Record 38 of Set 6 | mezen
# Processing Record 39 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 6 | lesosibirsk
# Processing Record 42 of Set 6 | puksoozero
# Processing Record 43 of Set 6 | komsomolskiy
# Processing Record 44 of Set 6 | san rafael del sur
# Processing Record 45 of Set 6 | cabo san lucas
# Processing Record 46 of Set 6 | bajo baudo
# City not found. Skipping...
# Processing Record 47 of Set 6 | luchegorsk
# Processing Record 48 of Set 6 | singaraja
# Processing Record 49 of Set 6 | batemans bay
# Processing Record 50 of Set 6 | provideniya
# Processing Record 1 of Set 7 | san vicente
# Processing Record 2 of Set 7 | lata
# Processing Record 3 of Set 7 | erzin
# Processing Record 4 of Set 7 | sao gabriel da cachoeira
# Processing Record 5 of Set 7 | moskovskoye
# Processing Record 6 of Set 7 | makamba
# Processing Record 7 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 7 | fairbanks
# Processing Record 9 of Set 7 | vaasa
# Processing Record 10 of Set 7 | port-gentil
# Processing Record 11 of Set 7 | hobart
# Processing Record 12 of Set 7 | kourou
# Processing Record 13 of Set 7 | sabancuy
# Processing Record 14 of Set 7 | clarence town
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 7 | moron
# Processing Record 18 of Set 7 | naze
# Processing Record 19 of Set 7 | mutis
# Processing Record 20 of Set 7 | mersing
# Processing Record 21 of Set 7 | melbourne
# Processing Record 22 of Set 7 | novoagansk
# Processing Record 23 of Set 7 | nhulunbuy
# Processing Record 24 of Set 7 | sao filipe
# Processing Record 25 of Set 7 | saint-georges
# Processing Record 26 of Set 7 | hurghada
# Processing Record 27 of Set 7 | moorhead
# Processing Record 28 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 7 | kudahuvadhoo
# Processing Record 30 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 7 | laguna
# Processing Record 32 of Set 7 | berdigestyakh
# Processing Record 33 of Set 7 | oistins
# Processing Record 34 of Set 7 | novyy urengoy
# Processing Record 35 of Set 7 | bocas del toro
# Processing Record 36 of Set 7 | toulepleu
# City not found. Skipping...
# Processing Record 37 of Set 7 | zvenyhorodka
# Processing Record 38 of Set 7 | moussoro
# Processing Record 39 of Set 7 | san quintin
# Processing Record 40 of Set 7 | mugur-aksy
# Processing Record 41 of Set 7 | tando jam
# Processing Record 42 of Set 7 | tual
# Processing Record 43 of Set 7 | mahibadhoo
# Processing Record 44 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 45 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 7 | bathsheba
# Processing Record 47 of Set 7 | otane
# Processing Record 48 of Set 7 | conde
# Processing Record 49 of Set 7 | clyde river
# Processing Record 50 of Set 7 | belaya gora
# Processing Record 1 of Set 8 | magadan
# Processing Record 2 of Set 8 | ostrovnoy
# Processing Record 3 of Set 8 | barrow
# Processing Record 4 of Set 8 | robertsport
# Processing Record 5 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 8 | zonguldak
# Processing Record 7 of Set 8 | egvekinot
# Processing Record 8 of Set 8 | manoel urbano
# Processing Record 9 of Set 8 | kondopoga
# Processing Record 10 of Set 8 | bonnyville
# Processing Record 11 of Set 8 | isla vista
# Processing Record 12 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 8 | maniitsoq
# Processing Record 14 of Set 8 | jose de freitas
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | katobu
# Processing Record 17 of Set 8 | vikhorevka
# Processing Record 18 of Set 8 | pangnirtung
# Processing Record 19 of Set 8 | kaili
# Processing Record 20 of Set 8 | trincomalee
# Processing Record 21 of Set 8 | bambous virieux
# Processing Record 22 of Set 8 | macaubas
# Processing Record 23 of Set 8 | russell
# Processing Record 24 of Set 8 | wajima
# Processing Record 25 of Set 8 | marsh harbour
# Processing Record 26 of Set 8 | saint george
# Processing Record 27 of Set 8 | qandala
# Processing Record 28 of Set 8 | japura
# Processing Record 29 of Set 8 | oudtshoorn
# Processing Record 30 of Set 8 | mariestad
# Processing Record 31 of Set 8 | saint-pierre
# Processing Record 32 of Set 8 | san cristobal
# Processing Record 33 of Set 8 | baruun-urt
# Processing Record 34 of Set 8 | martinsville
# Processing Record 35 of Set 8 | rock sound
# Processing Record 36 of Set 8 | kupang
# Processing Record 37 of Set 8 | oktyabrskoye
# Processing Record 38 of Set 8 | longyearbyen
# Processing Record 39 of Set 8 | bhadra
# Processing Record 40 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 41 of Set 8 | dhidhdhoo
# Processing Record 42 of Set 8 | ambon
# Processing Record 43 of Set 8 | bilma
# Processing Record 44 of Set 8 | galashki
# Processing Record 45 of Set 8 | bukama
# Processing Record 46 of Set 8 | asfi
# Processing Record 47 of Set 8 | altay
# Processing Record 48 of Set 8 | shaoguan
# Processing Record 49 of Set 8 | kozelsk
# Processing Record 50 of Set 8 | kalabo
# Processing Record 1 of Set 9 | quatre cocos
# Processing Record 2 of Set 9 | ondjiva
# Processing Record 3 of Set 9 | chokurdakh
# Processing Record 4 of Set 9 | yasnyy
# Processing Record 5 of Set 9 | iwanai
# Processing Record 6 of Set 9 | morrope
# Processing Record 7 of Set 9 | the pas
# Processing Record 8 of Set 9 | grindavik
# Processing Record 9 of Set 9 | bengkulu
# Processing Record 10 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 9 | mao
# Processing Record 12 of Set 9 | wagga wagga
# Processing Record 13 of Set 9 | nizhnevartovsk
# Processing Record 14 of Set 9 | kumluca
# Processing Record 15 of Set 9 | smithers
# Processing Record 16 of Set 9 | almazar
# Processing Record 17 of Set 9 | isiro
# Processing Record 18 of Set 9 | kidal
# Processing Record 19 of Set 9 | saint-francois
# Processing Record 20 of Set 9 | surt
# Processing Record 21 of Set 9 | jamame
# Processing Record 22 of Set 9 | owo
# Processing Record 23 of Set 9 | brigantine
# Processing Record 24 of Set 9 | urumita
# Processing Record 25 of Set 9 | san carlos de bariloche
# Processing Record 26 of Set 9 | shingu
# Processing Record 27 of Set 9 | beamsville
# Processing Record 28 of Set 9 | vredendal
# Processing Record 29 of Set 9 | dauriya
# Processing Record 30 of Set 9 | ilulissat
# Processing Record 31 of Set 9 | mirabad
# Processing Record 32 of Set 9 | kalmunai
# Processing Record 33 of Set 9 | jutai
# Processing Record 34 of Set 9 | chifeng
# Processing Record 35 of Set 9 | morondava
# Processing Record 36 of Set 9 | muzhi
# Processing Record 37 of Set 9 | pisco
# Processing Record 38 of Set 9 | chake chake
# Processing Record 39 of Set 9 | safranbolu
# Processing Record 40 of Set 9 | cordoba
# Processing Record 41 of Set 9 | mana
# Processing Record 42 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 9 | tarapur
# Processing Record 44 of Set 9 | yerofey pavlovich
# Processing Record 45 of Set 9 | rocha
# Processing Record 46 of Set 9 | rajakhera
# Processing Record 47 of Set 9 | arlit
# Processing Record 48 of Set 9 | vao
# Processing Record 49 of Set 9 | biak
# Processing Record 50 of Set 9 | richards bay
# Processing Record 1 of Set 10 | lappeenranta
# Processing Record 2 of Set 10 | provost
# Processing Record 3 of Set 10 | ovalle
# Processing Record 4 of Set 10 | kuytun
# Processing Record 5 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 6 of Set 10 | montargis
# Processing Record 7 of Set 10 | pingliang
# Processing Record 8 of Set 10 | domoni
# Processing Record 9 of Set 10 | kieta
# Processing Record 10 of Set 10 | svolvaer
# Processing Record 11 of Set 10 | lipin bor
# Processing Record 12 of Set 10 | mtwara
# Processing Record 13 of Set 10 | bonoua
# Processing Record 14 of Set 10 | galveston
# Processing Record 15 of Set 10 | coquimbo
# Processing Record 16 of Set 10 | bendigo
# Processing Record 17 of Set 10 | svetlogorsk
# Processing Record 18 of Set 10 | kyabe
# Processing Record 19 of Set 10 | roblin
# Processing Record 20 of Set 10 | ahipara
# Processing Record 21 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 10 | arnold
# Processing Record 23 of Set 10 | touros
# Processing Record 24 of Set 10 | kushima
# Processing Record 25 of Set 10 | beloha
# Processing Record 26 of Set 10 | abashiri
# Processing Record 27 of Set 10 | fort nelson
# Processing Record 28 of Set 10 | avenal
# Processing Record 29 of Set 10 | havre-saint-pierre
# Processing Record 30 of Set 10 | khani
# Processing Record 31 of Set 10 | sept-iles
# Processing Record 32 of Set 10 | timra
# Processing Record 33 of Set 10 | roald
# Processing Record 34 of Set 10 | aranda de duero
# Processing Record 35 of Set 10 | kununurra
# Processing Record 36 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 10 | lagoa
# Processing Record 38 of Set 10 | colares
# Processing Record 39 of Set 10 | atar
# Processing Record 40 of Set 10 | santa isabel do rio negro
# Processing Record 41 of Set 10 | marshalltown
# Processing Record 42 of Set 10 | bose
# Processing Record 43 of Set 10 | luquillo
# Processing Record 44 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 45 of Set 10 | houston
# Processing Record 46 of Set 10 | umea
# Processing Record 47 of Set 10 | adrar
# Processing Record 48 of Set 10 | turbat
# Processing Record 49 of Set 10 | high prairie
# Processing Record 50 of Set 10 | goroka
# Processing Record 1 of Set 11 | nokaneng
# Processing Record 2 of Set 11 | fayaoue
# Processing Record 3 of Set 11 | cukai
# Processing Record 4 of Set 11 | skibotn
# Processing Record 5 of Set 11 | izumo
# Processing Record 6 of Set 11 | salvador
# Processing Record 7 of Set 11 | kokopo
# Processing Record 8 of Set 11 | robore
# Processing Record 9 of Set 11 | sai buri
# Processing Record 10 of Set 11 | paamiut
# Processing Record 11 of Set 11 | lang suan
# Processing Record 12 of Set 11 | djambala
# Processing Record 13 of Set 11 | yei
# Processing Record 14 of Set 11 | kyzyl-suu
# Processing Record 15 of Set 11 | miami
# Processing Record 16 of Set 11 | bonito
# Processing Record 17 of Set 11 | romodanovo
# Processing Record 18 of Set 11 | mata
# Processing Record 19 of Set 11 | semme
# Processing Record 20 of Set 11 | hershey
# Processing Record 21 of Set 11 | namibe
# Processing Record 22 of Set 11 | lucapa
# Processing Record 23 of Set 11 | esperance
# Processing Record 24 of Set 11 | sanming
# Processing Record 25 of Set 11 | linxia
# Processing Record 26 of Set 11 | aklavik
# Processing Record 27 of Set 11 | nelson bay
# Processing Record 28 of Set 11 | disna
# Processing Record 29 of Set 11 | luwuk
# Processing Record 30 of Set 11 | rio gallegos
# Processing Record 31 of Set 11 | porto novo
# Processing Record 32 of Set 11 | amapa
# Processing Record 33 of Set 11 | beroroha
# Processing Record 34 of Set 11 | daru
# Processing Record 35 of Set 11 | tigbao
# Processing Record 36 of Set 11 | plastun
# Processing Record 37 of Set 11 | siteki
# Processing Record 38 of Set 11 | kirakira
# Processing Record 39 of Set 11 | tuatapere
# Processing Record 40 of Set 11 | maningrida
# Processing Record 41 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 42 of Set 11 | mareeba
# Processing Record 43 of Set 11 | katherine
# Processing Record 44 of Set 11 | dalvik
# Processing Record 45 of Set 11 | lorengau
# Processing Record 46 of Set 11 | catalina
# Processing Record 47 of Set 11 | zhangye
# Processing Record 48 of Set 11 | qui nhon
# Processing Record 49 of Set 11 | mitsamiouli
# Processing Record 50 of Set 11 | tapes
# Processing Record 1 of Set 12 | alta floresta
# Processing Record 2 of Set 12 | burica
# City not found. Skipping...
# Processing Record 3 of Set 12 | tarko-sale
# Processing Record 4 of Set 12 | tateyama
# Processing Record 5 of Set 12 | puerto montt
# Processing Record 6 of Set 12 | imbituba
# Processing Record 7 of Set 12 | maridi
# Processing Record 8 of Set 12 | zemio
# Processing Record 9 of Set 12 | sault sainte marie
# Processing Record 10 of Set 12 | nakhon phanom
# Processing Record 11 of Set 12 | la romana
# Processing Record 12 of Set 12 | samarai
# Processing Record 13 of Set 12 | srednekolymsk
# Processing Record 14 of Set 12 | kautokeino
# Processing Record 15 of Set 12 | chara
# Processing Record 16 of Set 12 | sabang
# Processing Record 17 of Set 12 | college
# Processing Record 18 of Set 12 | aksu
# Processing Record 19 of Set 12 | ucluelet
# Processing Record 20 of Set 12 | syamzha
# Processing Record 21 of Set 12 | moose factory
# Processing Record 22 of Set 12 | ponta pora
# Processing Record 23 of Set 12 | kargil
# Processing Record 24 of Set 12 | koutsouras
# Processing Record 25 of Set 12 | lieksa
# Processing Record 26 of Set 12 | naspur
# Processing Record 27 of Set 12 | moree
# Processing Record 28 of Set 12 | ust-omchug
# Processing Record 29 of Set 12 | okato
# Processing Record 30 of Set 12 | general roca
# Processing Record 31 of Set 12 | mandalgovi
# Processing Record 32 of Set 12 | newport
# Processing Record 33 of Set 12 | borba
# Processing Record 34 of Set 12 | chimore
# Processing Record 35 of Set 12 | yibin
# Processing Record 36 of Set 12 | talcahuano
# Processing Record 37 of Set 12 | velykoploske
# Processing Record 38 of Set 12 | sri aman
# Processing Record 39 of Set 12 | mukhen
# Processing Record 40 of Set 12 | parati
# Processing Record 41 of Set 12 | pakxan
# Processing Record 42 of Set 12 | mapiripan
# Processing Record 43 of Set 12 | severo-yeniseyskiy
# Processing Record 44 of Set 12 | severnoye
# Processing Record 45 of Set 12 | vestmannaeyjar
# Processing Record 46 of Set 12 | porto walter
# Processing Record 47 of Set 12 | kilindoni
# Processing Record 48 of Set 12 | ust-kulom
# Processing Record 49 of Set 12 | lapua
# Processing Record 50 of Set 12 | antalaha
# Processing Record 1 of Set 13 | bejar
# Processing Record 2 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 13 | kenai
# Processing Record 5 of Set 13 | luba
# Processing Record 6 of Set 13 | cap-aux-meules
# Processing Record 7 of Set 13 | port augusta
# Processing Record 8 of Set 13 | dzerzhinsk
# Processing Record 9 of Set 13 | batagay-alyta
# Processing Record 10 of Set 13 | sampit
# Processing Record 11 of Set 13 | rorvik
# Processing Record 12 of Set 13 | henties bay
# Processing Record 13 of Set 13 | madang
# Processing Record 14 of Set 13 | batticaloa
# Processing Record 15 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 13 | farkhor
# Processing Record 17 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 18 of Set 13 | hobyo
# Processing Record 19 of Set 13 | gamba
# Processing Record 20 of Set 13 | halifax
# Processing Record 21 of Set 13 | mumbwa
# Processing Record 22 of Set 13 | cidreira
# Processing Record 23 of Set 13 | semey
# Processing Record 24 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 13 | mayumba
# Processing Record 26 of Set 13 | katangli
# Processing Record 27 of Set 13 | manavalakurichi
# Processing Record 28 of Set 13 | okhotsk
# Processing Record 29 of Set 13 | kabalo
# Processing Record 30 of Set 13 | tatarka
# Processing Record 31 of Set 13 | luderitz
# Processing Record 32 of Set 13 | akdepe
# Processing Record 33 of Set 13 | phan thiet
# Processing Record 34 of Set 13 | wanaraja
# Processing Record 35 of Set 13 | iqaluit
# Processing Record 36 of Set 13 | hanna
# Processing Record 37 of Set 13 | peniche
# Processing Record 38 of Set 13 | goure
# Processing Record 39 of Set 13 | san javier
# Processing Record 40 of Set 13 | camopi
# Processing Record 41 of Set 13 | finschhafen
# Processing Record 42 of Set 13 | porto-vecchio
# Processing Record 43 of Set 13 | haines junction
# Processing Record 44 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 45 of Set 13 | gazli
# Processing Record 46 of Set 13 | muzquiz
# City not found. Skipping...
# Processing Record 47 of Set 13 | burnie
# Processing Record 48 of Set 13 | ust-kuyga
# Processing Record 49 of Set 13 | matagami
# Processing Record 50 of Set 13 | rockingham
# Processing Record 1 of Set 14 | grand gaube
# Processing Record 2 of Set 14 | kedrovyy
# Processing Record 3 of Set 14 | avera
# Processing Record 4 of Set 14 | kodinsk
# Processing Record 5 of Set 14 | pahrump
# Processing Record 6 of Set 14 | marawi
# Processing Record 7 of Set 14 | point pleasant
# Processing Record 8 of Set 14 | fereydun kenar
# Processing Record 9 of Set 14 | bom jesus
# Processing Record 10 of Set 14 | kristiansund
# Processing Record 11 of Set 14 | te anau
# Processing Record 12 of Set 14 | bayeux
# Processing Record 13 of Set 14 | la asuncion
# Processing Record 14 of Set 14 | vardo
# Processing Record 15 of Set 14 | matay
# Processing Record 16 of Set 14 | ranong
# Processing Record 17 of Set 14 | ola
# Processing Record 18 of Set 14 | sayyan
# Processing Record 19 of Set 14 | itaituba
# Processing Record 20 of Set 14 | christchurch
# Processing Record 21 of Set 14 | gat
# Processing Record 22 of Set 14 | karlstad
# Processing Record 23 of Set 14 | otavi
# Processing Record 24 of Set 14 | plettenberg bay
# Processing Record 25 of Set 14 | matara
# Processing Record 26 of Set 14 | samarinda
# Processing Record 27 of Set 14 | jaisalmer
# Processing Record 28 of Set 14 | banda aceh
# Processing Record 29 of Set 14 | puerto narino
# Processing Record 30 of Set 14 | bonthe
# Processing Record 31 of Set 14 | tilichiki
# Processing Record 32 of Set 14 | sompeta
# Processing Record 33 of Set 14 | fenoarivo
# Processing Record 34 of Set 14 | vagur
# Processing Record 35 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 36 of Set 14 | tabas
# Processing Record 37 of Set 14 | colquechaca
# Processing Record 38 of Set 14 | dibaya
# City not found. Skipping...
# Processing Record 39 of Set 14 | vikulovo
# Processing Record 40 of Set 14 | taoudenni
# Processing Record 41 of Set 14 | dingle
# Processing Record 42 of Set 14 | bobonong
# City not found. Skipping...
# Processing Record 43 of Set 14 | port-cartier
# Processing Record 44 of Set 14 | borogontsy
# Processing Record 45 of Set 14 | les escoumins
# Processing Record 46 of Set 14 | riberalta
# Processing Record 47 of Set 14 | nuuk
# Processing Record 48 of Set 14 | makung
# City not found. Skipping...
# Processing Record 49 of Set 14 | chapais
# Processing Record 50 of Set 14 | saint anthony
# Processing Record 1 of Set 15 | muros
# Processing Record 2 of Set 15 | san rafael
# Processing Record 3 of Set 15 | uglegorskiy
# Processing Record 4 of Set 15 | chanika
# Processing Record 5 of Set 15 | mundo nuevo
# Processing Record 6 of Set 15 | urucara
# Processing Record 7 of Set 15 | jumla
# Processing Record 8 of Set 15 | izazi
# Processing Record 9 of Set 15 | mountain home
# Processing Record 10 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 15 | farim
# Processing Record 12 of Set 15 | tsentralnyy
# City not found. Skipping...
# Processing Record 13 of Set 15 | fougeres
# Processing Record 14 of Set 15 | sibu
# Processing Record 15 of Set 15 | sundarnagar
# Processing Record 16 of Set 15 | galeana
# Processing Record 17 of Set 15 | voi
# Processing Record 18 of Set 15 | watrous
# Processing Record 19 of Set 15 | dalbandin
# Processing Record 20 of Set 15 | george town
# Processing Record 21 of Set 15 | vanimo
# Processing Record 22 of Set 15 | pilao arcado
# City not found. Skipping...
# Processing Record 23 of Set 15 | alibag
# Processing Record 24 of Set 15 | tanout
# Processing Record 25 of Set 15 | durango
# Processing Record 26 of Set 15 | sherlovaya gora
# Processing Record 27 of Set 15 | arvika
# Processing Record 28 of Set 15 | balaipungut
# Processing Record 29 of Set 15 | manicaragua
# Processing Record 30 of Set 15 | muti
# Processing Record 31 of Set 15 | honiara
# Processing Record 32 of Set 15 | erdenet
# Processing Record 33 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 15 | manggar
# Processing Record 35 of Set 15 | powell river
# Processing Record 36 of Set 15 | willemstad
# Processing Record 37 of Set 15 | sobolevo
# Processing Record 38 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 39 of Set 15 | los llanos de aridane
# Processing Record 40 of Set 15 | pachora
# Processing Record 41 of Set 15 | pajapan
# Processing Record 42 of Set 15 | pavlodar
# Processing Record 43 of Set 15 | stamsund
# City not found. Skipping...
# Processing Record 44 of Set 15 | tvoroyri
# Processing Record 45 of Set 15 | kipini
# Processing Record 46 of Set 15 | sokolo
# Processing Record 47 of Set 15 | ocean city
# Processing Record 48 of Set 15 | dawlatabad
# Processing Record 49 of Set 15 | terrace
# Processing Record 50 of Set 15 | sovetskiy
# Processing Record 1 of Set 16 | praya
# Processing Record 2 of Set 16 | quelimane
# Processing Record 3 of Set 16 | churapcha
# Processing Record 4 of Set 16 | sirsi
# Processing Record 5 of Set 16 | sulzbach-rosenberg
# Processing Record 6 of Set 16 | gillette
# Processing Record 7 of Set 16 | itoman
# Processing Record 8 of Set 16 | nueva loja
# Processing Record 9 of Set 16 | san jose
# Processing Record 10 of Set 16 | muyezerskiy
# Processing Record 11 of Set 16 | gilgit
# Processing Record 12 of Set 16 | saint-augustin
# Processing Record 13 of Set 16 | skara
# Processing Record 14 of Set 16 | pittsfield
# Processing Record 15 of Set 16 | vartoapele-de-jos
# City not found. Skipping...
# Processing Record 16 of Set 16 | barranca
# Processing Record 17 of Set 16 | tigil
# Processing Record 18 of Set 16 | bontang
# Processing Record 19 of Set 16 | ust-nera
# Processing Record 20 of Set 16 | diego de almagro
# Processing Record 21 of Set 16 | umm lajj
# Processing Record 22 of Set 16 | lasa
# Processing Record 23 of Set 16 | ulundi
# Processing Record 24 of Set 16 | mikhaylov
# Processing Record 25 of Set 16 | diffa
# Processing Record 26 of Set 16 | mogadishu
# Processing Record 27 of Set 16 | poplar bluff
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 720

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Upernavik  72.79  -56.15     38.75        81          80        4.79
# 1        Rikitea -23.12 -134.97     69.15        84          92       13.87
# 2           Kaeo -35.10  173.78     54.00         3           5        1.99
# 3       Katsuura  35.13  140.30     75.20        88          75       14.99
# 4      Mahebourg -20.41   57.70     71.60        88          40       11.41
# 5        Ushuaia -54.80  -68.30     32.00        81          75        6.93
# 6        Margate  51.38    1.39     64.99        50          94        4.00
# 7        Kavieng  -2.57  150.80     83.23        78          38        9.44
# 8  Half Moon Bay  37.46 -122.43     61.00        93          90        6.93
# 9       Miquelon  47.10  -56.38     60.80        77          75       28.86
#
#   Country Current Description
# 0      GL       broken clouds
# 1      PF          light rain
# 2      NZ           clear sky
# 3      JP       broken clouds
# 4      MU         shower rain
# 5      AR       broken clouds
# 6      GB     overcast clouds
# 7      PG          light rain
# 8      US                mist
# 9      PM       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Upernavik      GL  72.79  -56.15     38.75        81          80
# 1        Rikitea      PF -23.12 -134.97     69.15        84          92
# 2           Kaeo      NZ -35.10  173.78     54.00         3           5
# 3       Katsuura      JP  35.13  140.30     75.20        88          75
# 4      Mahebourg      MU -20.41   57.70     71.60        88          40
# 5        Ushuaia      AR -54.80  -68.30     32.00        81          75
# 6        Margate      GB  51.38    1.39     64.99        50          94
# 7        Kavieng      PG  -2.57  150.80     83.23        78          38
# 8  Half Moon Bay      US  37.46 -122.43     61.00        93          90
# 9       Miquelon      PM  47.10  -56.38     60.80        77          75
#
#    Wind Speed Current Description
# 0        4.79       broken clouds
# 1       13.87          light rain
# 2        1.99           clear sky
# 3       14.99       broken clouds
# 4       11.41         shower rain
# 5        6.93       broken clouds
# 6        4.00     overcast clouds
# 7        9.44          light rain
# 8        6.93                mist
# 9       28.86       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-85c3a7d8006d> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     182             close = False
#     183         else:
# --> 184             f, handles = get_handle(
#     185                 self.path_or_buf,
#     186                 self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
